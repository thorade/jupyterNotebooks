# %% [markdown]
# * Open a normal Windows command prompt, then run:
# * `C:\OCT-stable-r5927\setenv.bat 64`
# * `where python`
# * `cd "%USERPROFILE%\Documents"`
# * `jupyter notebook`

# %%
import os, sys, pyjmi, pymodelica, pyfmi
print(sys.version)
print(pyjmi.__version__)
print(pymodelica.__version__)
print(pyfmi.__version__)
print(os.environ.get('MODELICAPATH'))
# Out:
# 2.7.13 (v2.7.13:a06454b1afa1, Dec 17 2016, 20:53:40) [MSC v.1500 64 bit (AMD64)]
# OCT-stable-r8473_JM-stable-r12633
# OCT-stable-r8473_JM-stable-r12633
# 2.5
# None

# %%
# Import the RLC example
from pyjmi.examples import RLC

# Run the RLC example and plot results
RLC.run_demo()
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 790
#  Number of function evaluations                  : 869
#  Number of Jacobian evaluations                  : 14
#  Number of function eval. due to Jacobian eval.  : 42
#  Number of error test failures                   : 1
#  Number of nonlinear iterations                  : 865
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-06
#  Tolerances (relative)    : 0.0001
#
# Simulation interval    : 0.0 - 30.0 seconds.
# Elapsed simulation time: 0.0550617 seconds.
